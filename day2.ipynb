# %%
# #
# #
# def marks(marks_list):

#     for m in marks_list:
#         print(m)

# student_marks = [85, 92, 78, 95]


# marks(student_marks)

# #
# def marks(a):
#     for i in range(len(a)):
#         print(a[i])

# marks([10, 20, 30, 40, 50])


# #
# def power(a, b):
#     print(a**b)

# # Output: 25 (5 raised to the power of 2)
# power(5, 2)

# # Output: 32 (2 raised to the power of 5)
# power(2, 5)

# # Output: 32 (Explicitly assigning b=5 and a=2, so it's still 2 raised to the power of 5)
# power(b=5, a=2)


# # question
# # def address() :
# #     for i in range(len(a)):
# #       for j in range(len(a[i])):
# #         print(a[i][j])

# # address(["hello" , "Yash"])

# # def address(a):
# #     for i in range(len(a)):
# #         for j in range(len(a[i])):
# #             print(a[i][j])
# # address(["hello","Yash"])


#
def sum(a,b) :
  return a+b
result =
# Out:
#   File "/tmp/ipykernel_648/4186714390.py", line 53
#     result =
#              ^
# SyntaxError: invalid syntax

# %%
# lambda function [lambda arguments : expression]
add = lambda x: x
print(add(100))

sum = lambda x,y: x+y
print(sum(10,20))

a = lambda x: x
print(a([10,20,30,40]))

show = lambda *a: print(a)
show(1, 2, 3)
show("Yash", "Hello")
# Out:
# 100
# 30
# [10, 20, 30, 40]
# (1, 2, 3)
# ('Yash', 'Hello')

# %%
# list comprehensions [expression for item in iterable]
print([i for i in range(5)])
# example
l = [10,20,30,40,50]
print([l[i] for i in range (len(l))])
# Out:
# [0, 1, 2, 3, 4]
# [10, 20, 30, 40, 50]

# %%
# list
d= {"name":"hello" , "age":20}

print(d.keys())
print(d.values())

for i in d.keys() :
  print("keys=" ,i)
  print("value=" ,d[i])
# Out:
# dict_keys(['name', 'age'])
# dict_values(['hello', 20])
# keys= name
# value= hello
# keys= age
# value= 20
