# %%
print("hello")
# Out:
# hello

# %%
name = 10
name1 = 10
print(name == name1)
# Out:
# True

# %%
print (name is name1)
print(id(name))
print(id(name1))
# Out:
# True
# 11645640
# 11645640

# %%
# num1 =-5    (-5 to 256) -> both var point on same adderess
num2 =-5
print(num1 == num2)
print(id(num1))
print(id(num2))
# Out:
# True
# 11645160
# 11645160

# %%
num1 =260
num2 =260
print(num1 == num2)
print(num1 is num2)
print(id(num1))
print(id(num2))
# Out:
# True
# False
# 134546048446704
# 134546048449776

# %%
num1 =[1,2,3]
num2 =[1,2,3]

print(num1 == num2)
print(num1 is num2)
print(id(num1))
print(id(num2))
# Out:
# True
# False
# 134545480990592
# 134545480234240

# %%
# if
# num1 = 10
# num2 =20
# if num1 < num2 :
#   print(num2)

# if else
# num1 = int(input("enter the num1:"))
# if num1 :
#   print("num:" , num1)
# else:
#   print("zero:" , num1)

# if elif else
age = int(input("Enter the num:"))
if age == 18 :
  print("your age is :" , age)
elif age > 18 :
  print("you are above than 18 :" , age)
else :
  print("you are less than 18 :" , age)
# Out:
# Enter the num:12
# you are less than : 12

# %%
# student marks user input
marks = int(input("Enter your marks :"))
if marks > 60:
  print("Your grade is : C" )
elif marks > 75:
  print("your grade is : B"  )
elif marks >90 :
  print("your grade is : A" )
else :
  print("fail")
# Out:
# Enter your marks :66
# Your grade is : C

# %%
print(22*4)
print(22 << 2)
# Out:
# 88
# 88
